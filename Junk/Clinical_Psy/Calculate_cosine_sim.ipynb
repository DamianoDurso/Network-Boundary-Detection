# %% [markdown]
# ## In the code below we perform the following steps
#
# - Read in the item text data (https://chatgpt.com/share/66fa7c2a-101c-800b-88a5-7334934a995d)
# - Calculate item embeddings
# - Reverse item embeddings if necessary (we don't have reversed items here, but this approach may be unoptimal. In case of reversed items we could use fine-tuned model as in Hommell (2024))
# - Compute cosine similarities
# - Store results

# %% [markdown]
# ### 1- Read in the item text data

# %%
import pandas as pd
import numpy as np
# read in file with items text etc.
df_items = pd.read_csv('./Data/dass_21_items_mod_2.csv')
df_items.head()
# Out:
#    Number      Factor                                               Item  \
# 0       1  Depression  I couldn't seem to experience any positive fee...
# 1       2  Depression  I found it difficult to work up the initiative...
# 2       3  Depression      I felt that I had nothing to look forward to.
# 3       4  Depression                      I felt down-hearted and blue.
# 4       5  Depression  I was unable to become enthusiastic about anyt...
#
#                                            Item_simp  \
# 0  when feeling depressed I Couldn't seem to expe...
# 1  when feeling depressed I Found it difficult to...
# 2  when feeling depressed I Felt that I had nothi...
# 3  when feeling depressed I Felt down-hearted and...
# 4  when feeling depressed I was Unable to become ...
#
#                                             Item_mod Sign
# 0  Depression is characterised principally by a l...    +
# 1  Depression is characterised principally by a l...    +
# 2  Depression is characterised principally by a l...    +
# 3  Depression is characterised principally by a l...    +
# 4  Depression is characterised principally by a l...    +

# %% [markdown]
# ### 2- Calculate embeddings (and reverse code if necessary)

# %%
# First we create a list of models (all multilinguals here)
models = ['nli-distilroberta-base-v2',
          'all-mpnet-base-v2',
          'sentence-transformers/all-MiniLM-L6-v2',
          'intfloat/e5-large-v2',
          'LaBSE'] #consider adding the finetuned model for psicometrista

# Import the necessary libraries and functions
from sentence_transformers import SentenceTransformer, util

# Create an empty data frame, which we will then populate with the different type of embeddings
facet_embeddings_sentences = pd.DataFrame()

for mod in models:
    model = SentenceTransformer(mod) #call the model
    item_embed = [] #create list for item-level embed
    item_embed_rev = [] #create list for item-level embed accounting for sign
    for item in range(0,len(df_items['Number'])): #loop over all the items
    #encode items
        item_embed.append(model.encode(df_items['Item'].iloc[item]))
        if df_items['Sign'].iloc[item][0] == '-': #if items is negatively keyed, reverse the embeddings
            item_embed_rev.append(model.encode(df_items['Item'].iloc[item])*-1)
        else:
            item_embed_rev.append(model.encode(df_items['Item'].iloc[item]))
    df_items[mod + '_embeddings'] = item_embed #then, we append the two item-level embeddings list and give them a name based on the model we used
    df_items[mod + '_embeddings_rev'] = item_embed_rev
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/67.8k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/201 [00:00<?, ?B/s]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
df_items
# Out:
#     Number      Factor                                               Item  \
# 0        1  Depression  I couldn't seem to experience any positive fee...
# 1        2  Depression  I found it difficult to work up the initiative...
# 2        3  Depression      I felt that I had nothing to look forward to.
# 3        4  Depression                      I felt down-hearted and blue.
# 4        5  Depression  I was unable to become enthusiastic about anyt...
# 5        6  Depression            I felt I wasn't worth much as a person.
# 6        7  Depression                  I felt that life was meaningless.
# 7        8     Anxiety                I was aware of dryness of my mouth.
# 8        9     Anxiety  I experienced breathing difficulty (e.g., exce...
# 9       10     Anxiety      I experienced trembling (e.g., in the hands).
# 10      11     Anxiety  I was worried about situations in which I migh...
# 11      12     Anxiety                       I felt I was close to panic.
# 12      13     Anxiety  I was aware of the action of my heart in the a...
# 13      14     Anxiety             I felt scared without any good reason.
# 14      15      Stress                      I found it hard to wind down.
# 15      16      Stress              I tended to over-react to situations.
# 16      17      Stress   I felt that I was using a lot of nervous energy.
# 17      18      Stress                   I found myself getting agitated.
# 18      19      Stress                     I found it difficult to relax.
# 19      20      Stress  I was intolerant of anything that kept me from...
# 20      21      Stress                   I felt that I was rather touchy.
#
#                                             Item_simp  \
# 0   when feeling depressed I Couldn't seem to expe...
# 1   when feeling depressed I Found it difficult to...
# 2   when feeling depressed I Felt that I had nothi...
# 3   when feeling depressed I Felt down-hearted and...
# 4   when feeling depressed I was Unable to become ...
# 5   when feeling depressed I Felt I wasn't worth m...
# 6   when feeling depressed I Felt that life was me...
# 7   when feeling anxious I Aware of dryness of my ...
# 8   when feeling anxious I experienced breathing d...
# 9   when feeling anxious I Experienced trembling (...
# 10  when feeling anxious I Worried about situation...
# 11   when feeling anxious I Felt I was close to panic
# 12  when feeling anxious I was Aware of the action...
# 13  when feeling anxious I Felt scared without any...
# 14  when feeling anxious I Found it hard to wind down
# 15  when feeling stressed I Tended to over-react t...
# 16  when feeling stressed I Felt that I was using ...
# 17  when feeling stressed I Found myself getting a...
# 18  when feeling stressed I Found it difficult to ...
# 19  when feeling stressed I was intolerant of anyt...
# 20  when feeling stressed I Felt that I was rather...
#
#                                              Item_mod Sign  \
# 0   Depression is characterised principally by a l...    +
# 1   Depression is characterised principally by a l...    +
# 2   Depression is characterised principally by a l...    +
# 3   Depression is characterised principally by a l...    +
# 4   Depression is characterised principally by a l...    +
# 5   Depression is characterised principally by a l...    +
# 6   Depression is characterised principally by a l...    +
# 7   Anxiety is a relatively enduring state of anxi...    +
# 8   Anxiety is a relatively enduring state of anxi...    +
# 9   Anxiety is a relatively enduring state of anxi...    +
# 10  Anxiety is a relatively enduring state of anxi...    +
# 11  Anxiety is a relatively enduring state of anxi...    +
# 12  Anxiety is a relatively enduring state of anxi...    +
# 13  Anxiety is a relatively enduring state of anxi...    +
# 14  Stress is state of persistent arousal and tens...    +
# 15  Stress is state of persistent arousal and tens...    +
# 16  Stress is state of persistent arousal and tens...    +
# 17  Stress is state of persistent arousal and tens...    +
# 18  Stress is state of persistent arousal and tens...    +
# 19  Stress is state of persistent arousal and tens...    +
# 20  Stress is state of persistent arousal and tens...    +
#
#                  nli-distilroberta-base-v2_embeddings  \
# 0   [-0.41798195, -0.60875887, 0.41989467, -0.3381...
# 1   [-0.26888198, -0.49430892, 1.0279641, 0.863048...
# 2   [-0.71781987, -0.48583412, 0.17099401, -0.5182...
# 3   [-0.3016205, 0.2141138, -0.23003463, -0.434639...
# 13  [0.008355893, 0.018355276, -0.06299976, -0.030...
# 14  [-0.03177534, 0.01339561, -0.041719608, -0.083...
# 15  [-0.06737357, 0.02894921, -0.0118169105, -0.05...
# 16  [0.04446657, 0.026459849, 0.0059745433, -0.038...
# 17  [0.006689334, 0.012294056, -0.035039466, -0.07...
# 18  [-0.029101007, 0.042208195, 0.0036166126, -0.0...
# 19  [0.052607946, 0.010065092, -0.017785642, -0.06...
# 20  [0.02395871, 0.03256823, -0.041315768, -0.0676...
#
#                                  LaBSE_embeddings_rev
# 0   [-0.027827162, 0.05928395, -0.06475832, -0.049...
# 1   [0.034038432, -0.004301942, 0.0059101717, -0.0...
# 2   [0.034416497, 0.03162081, -0.059108265, -0.056...
# 3   [-0.05726779, 0.055614337, -0.0008938348, -0.0...
# 4   [0.018410865, 0.013755682, -0.064998284, -0.05...
# 5   [-0.018875614, 0.035567682, -0.0649392, -0.059...
# 6   [-0.02286053, -0.0254926, -0.040635087, -0.050...
# 7   [-0.014379178, -0.002829763, 0.0026872945, -0....
# 8   [-0.047368508, 0.045650344, -0.049365725, -0.0...
# 9   [-0.027833354, -0.004120173, -0.014727401, -0....
# 10  [0.010305842, 0.0118559105, 0.007681073, -0.05...
# 11  [-0.019697532, 0.027148517, -0.04442431, -0.07...
# 12  [-0.045240417, 0.04727998, -0.04275839, -0.050...
# 13  [0.008355893, 0.018355276, -0.06299976, -0.030...
# 14  [-0.03177534, 0.01339561, -0.041719608, -0.083...
# 15  [-0.06737357, 0.02894921, -0.0118169105, -0.05...
# 16  [0.04446657, 0.026459849, 0.0059745433, -0.038...
# 17  [0.006689334, 0.012294056, -0.035039466, -0.07...
# 18  [-0.029101007, 0.042208195, 0.0036166126, -0.0...
# 19  [0.052607946, 0.010065092, -0.017785642, -0.06...
# 20  [0.02395871, 0.03256823, -0.041315768, -0.0676...

# %% [markdown]
# ### Step 3 -  Compute cosine simlarities and store the data

# %%
# To avoid having too long names for the output datsets, we create a list of names, which we will then use to save the embedding cosine matrices
# make sure that the names here are meaningful and aligned with those of the one in the cell above.
model_short = ['distilroberta', 'mpnet', 'miniLM', 'e5', 'labse']

# Below, we loop over the different models we use for the study and compute the cosine sim. matrices.
for mod in range(0, len(models)):
  # create temporary empty lists for the item and one-pop method embeddings
  facet_embeddings_item = []

  #create cosine similarity matrix for each embedding calculation approach
  cosine_similarities_item = util.pytorch_cos_sim(df_items[models[mod] + '_embeddings'],df_items[models[mod] + '_embeddings']).numpy()

  # we don't have revesed items so code below is not necessary
  
  #fill diagonal with 1. This is done to avoid efa functions reading the cosine matrix as covariance
  np.fill_diagonal(cosine_similarities_item,1)


  #store results
  pd.DataFrame(cosine_similarities_item, columns = df_items['Item_simp'].unique(), index = df_items['Item_simp'].unique()).to_csv('./Data/cos_matrices/matrix_concatenated_item_'+model_short[mod]+'.csv', index = False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sentence_transformers/util.py:44: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:264.)
#   a = torch.tensor(a)
